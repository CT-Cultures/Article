# %%
import scrapy

# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is E411-13D6
#
#  Directory of C:\Users\User\Desktop\Github\Content\sources\NRTA\raw
#
# 11/24/2021  10:27 PM    <DIR>          .
# 11/24/2021  10:27 PM    <DIR>          ..
# 11/24/2021  10:27 PM    <DIR>          .ipynb_checkpoints
# 11/24/2021  10:28 PM    <DIR>          raw
# 11/24/2021  10:08 PM               249 scrapy.cfg
#                1 File(s)            249 bytes
#                4 Dir(s)  69,684,563,968 bytes free

# %%
# !scrapy startproject raw
# Out:
# Error: Module 'raw' already exists

# %%
# !scrapy crawl nrta
# Out:
# 2021-11-24 22:43:46 [scrapy.utils.log] INFO: Scrapy 2.4.1 started (bot: raw)
# 2021-11-24 22:43:46 [scrapy.utils.log] INFO: Versions: lxml 4.6.3.0, libxml2 2.9.12, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 21.7.0, Python 3.8.12 (default, Oct 12 2021, 03:01:40) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 21.0.0 (OpenSSL 1.1.1l  24 Aug 2021), cryptography 35.0.0, Platform Windows-10-10.0.19043-SP0
# 2021-11-24 22:43:46 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2021-11-24 22:43:46 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'raw',
#  'NEWSPIDER_MODULE': 'raw.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['raw.spiders']}
# 2021-11-24 22:43:46 [scrapy.extensions.telnet] INFO: Telnet Password: 468bcc553ea6e724
# 2021-11-24 22:43:46 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# ...

# %%
# !scrapy shell 'https://dsj.nrta.gov.cn/tims/site/views/applications.shanty?appName=changing'
# Out:
# 2021-11-24 22:48:02 [scrapy.utils.log] INFO: Scrapy 2.4.1 started (bot: raw)
# 2021-11-24 22:48:02 [scrapy.utils.log] INFO: Versions: lxml 4.6.3.0, libxml2 2.9.12, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 21.7.0, Python 3.8.12 (default, Oct 12 2021, 03:01:40) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 21.0.0 (OpenSSL 1.1.1l  24 Aug 2021), cryptography 35.0.0, Platform Windows-10-10.0.19043-SP0
# 2021-11-24 22:48:02 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2021-11-24 22:48:02 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'raw',
#  'DUPEFILTER_CLASS': 'scrapy.dupefilters.BaseDupeFilter',
#  'LOGSTATS_INTERVAL': 0,
#  'NEWSPIDER_MODULE': 'raw.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['raw.spiders']}
# 2021-11-24 22:48:02 [scrapy.extensions.telnet] INFO: Telnet Password: a9ed8c561a88ff2d
# 2021-11-24 22:48:02 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
# ...

# %%
url = 'https://dsj.nrta.gov.cn/tims/site/views/applications.shanty?appName=changing'
url.split('=')[-1]
# Out:
# 'changing'
